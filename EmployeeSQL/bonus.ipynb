# %% [markdown]
# # Bonus

# %% [markdown]
# Dependencies

# %%
# Must pip install psycopg2
# Dependencies and Setup
# %matplotlib notebook
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#connect to database
engine = create_engine('postgres://postgres:postgres@localhost:5432/employee_db')
conn = engine.connect()

# %% [markdown]
# Dataset

# %%
# query data
employee= pd.read_sql("SELECT titles.title,salaries.salary FROM salaries JOIN employees ON employees.emp_no=salaries.emp_no JOIN titles ON titles.title_id=employees.emp_title_id", conn)
employee.head()
# Out:
#               title  salary
# 0          Engineer   48973
# 1   Senior Engineer   40000
# 2  Technique Leader   43548
# 3             Staff   63377
# 4   Senior Engineer   40000

# %%
#average salary by title
employee_mean_groupby=employee.groupby("title").mean()
employee_mean_groupby
# Out:
#                           salary
# title
# Assistant Engineer  48564.434447
# Engineer            48535.336511
# Manager             51531.041667
# Senior Engineer     48506.799871
# Senior Staff        58550.172704
# Staff               58465.382850
# Technique Leader    48582.896092

# %% [markdown]
# Graphs

# %%
employee_mean_groupby.plot(kind="bar", facecolor="blue")
plt.title("Average Employee Salary by Title")
plt.ylabel("Salaries($)")
plt.xlabel("Employee Titles")
plt.show()
plt.tight_layout()
#Save Figure
plt.savefig("average_salary_by_title.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
